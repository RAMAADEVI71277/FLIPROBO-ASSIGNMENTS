# %%
import selenium
from selenium import webdriver 
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
import requests

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) onwww.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to bescraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,“Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of thedetails is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (6)\chromedriver.exe')
driver.get("https://www.flipkart.com/")

# %%
destination=driver.find_element(By.CLASS_NAME,"_3704LK")
destination.send_keys("pixel 4A")

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
url=[]
url_tag=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url_tag:
    url.append(i.get_attribute('href'))
print(url)
# Out:
# ['https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=9724b98a-6230-4f2b-bb98-e5e5e91fb81a.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=7hhg547y000000001671820226245&qH=9b26a23b2cff510d', 'https://www.flipkart.com/realme-c30-denim-black-32-gb/p/itmfcf69b2db5059?pid=MOBGF37G8TGKHFWJ&lid=LSTMOBGF37G8TGKHFWJIST95C&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=9724b98a-6230-4f2b-bb98-e5e5e91fb81a.MOBGF37G8TGKHFWJ.SEARCH&ppt=hp&ppn=homepage&ssid=7hhg547y000000001671820226245&qH=9b26a23b2cff510d', 'https://www.flipkart.com/realme-c30-lake-blue-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GTRVMRJVK&lid=LSTMOBGF37GTRVMRJVKRYAJNG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=9724b98a-6230-4f2b-bb9
# ...

# %%
b_name=[]
b_name_tag=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in b_name_tag:
    b_name.append(i.text.split('|'))

# %%
b_name
# Out:
# [['Google Pixel 4a (Just Black, 128 GB)'],
#  ['realme C30 (Denim Black, 32 GB)'],
#  ['realme C30 (Lake Blue, 32 GB)'],
#  ['realme C30 (Bamboo Green, 32 GB)'],
#  ['realme C30 (Denim Black, 32 GB)'],
#  ['realme C30 (Bamboo Green, 32 GB)'],
#  ['realme C30 (Lake Blue, 32 GB)'],
#  ['realme 10 Pro 5G (Hyperspace, 128 GB)'],
#  ['realme 10 Pro 5G (Hyperspace, 128 GB)'],
#  ['realme 10 Pro 5G (Nebula Blue, 128 GB)'],
#  ['realme 10 Pro 5G (Dark Matter, 128 GB)'],
#  ['vivo T1 44W (Midnight Galaxy, 128 GB)'],
#  ['realme 10 Pro+ 5G (Nebula Blue, 128 GB)'],
#  ['realme 10 Pro+ 5G (Dark Matter, 128 GB)'],
#  ['realme 10 Pro+ 5G (Hyperspace, 128 GB)'],
#  ['vivo T1 44W (Midnight Galaxy, 128 GB)'],
#  ['vivo T1 44W (Ice Dawn, 128 GB)'],
#  ['vivo T1 44W (Starry Sky, 128 GB)'],
#  ['realme C33 (Sandy Gold, 32 GB)'],
#  ['realme C33 (Night Sea, 32 GB)'],
#  ['realme C33 (Night Sea, 64 GB)'],
#  ['realme C33 (Aqua Blue, 64 GB)'],
#  ['realme C33 (Sandy Gold, 64 GB)'],
# ...

# %%
ram=[]
ram_tag=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]')
for i in ram_tag:
    ram.append(i.text.split('|')[0])

# %%
ram
# Out:
# ['6 GB RAM ',
#  '2 GB RAM ',
#  '2 GB RAM ',
#  '2 GB RAM ',
#  '3 GB RAM ',
#  '3 GB RAM ',
#  '3 GB RAM ',
#  '6 GB RAM ',
#  '8 GB RAM ',
#  '8 GB RAM ',
#  '6 GB RAM ',
#  '4 GB RAM ',
#  '8 GB RAM ',
#  '6 GB RAM ',
#  '8 GB RAM ',
#  '6 GB RAM ',
#  '4 GB RAM ',
#  '6 GB RAM ',
#  '3 GB RAM ',
#  '3 GB RAM ',
#  '4 GB RAM ',
#  '4 GB RAM ',
#  '4 GB RAM ',
#  '8 GB RAM ']

# %%
rom=[]
rom_tag=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]')
for i in rom_tag:
    rom.append(i.text.split('|')[1])

# %%
rom
# Out:
# [' 128 GB ROM\n14.76 cm (5.81 inch) Full HD+ Display\n12.2MP Rear Camera ',
#  ' 32 GB ROM ',
#  ' 32 GB ROM ',
#  ' 32 GB ROM ',
#  ' 32 GB ROM ',
#  ' 32 GB ROM ',
#  ' 32 GB ROM ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM\n17.02 cm (6.7 inch) Full HD+ Display\n108MP + 8MP + 2MP ',
#  ' 128 GB ROM\n17.02 cm (6.7 inch) Full HD+ Display\n108MP + 8MP + 2MP ',
#  ' 128 GB ROM\n17.02 cm (6.7 inch) Full HD+ Display\n108MP + 8MP + 2MP ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM ',
#  ' 128 GB ROM ',
#  ' 32 GB ROM ',
#  ' 32 GB ROM ',
#  ' 64 GB ROM ',
#  ' 64 GB ROM ',
#  ' 64 GB ROM ',
#  ' 128 GB ROM ']

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,('//div[@class="_30jeq3 _1_WHN1"]'))
for i in price_tag:
    price.append(i.text)

# %%
price
# Out:
# ['₹31,999',
#  '₹5,999',
#  '₹5,999',
#  '₹5,999',
#  '₹6,999',
#  '₹6,999',
#  '₹6,999',
#  '₹18,999',
#  '₹19,999',
#  '₹19,999',
#  '₹18,999',
#  '₹14,499',
#  '₹25,999',
#  '₹24,999',
#  '₹25,999',
#  '₹15,999',
#  '₹14,499',
#  '₹15,999',
#  '₹8,999',
#  '₹8,999',
#  '₹9,999',
#  '₹9,999',
#  '₹9,999',
#  '₹17,999']

# %%
df=pd.DataFrame({'Brand name':b_name,'RAM':ram,'ROM':rom,'PRICE':price,'URL':url})
df
# Out:
#                                    Brand name        RAM  \
# 0      [Google Pixel 4a (Just Black, 128 GB)]  6 GB RAM
# 1           [realme C30 (Denim Black, 32 GB)]  2 GB RAM
# 2             [realme C30 (Lake Blue, 32 GB)]  2 GB RAM
# 3          [realme C30 (Bamboo Green, 32 GB)]  2 GB RAM
# 4           [realme C30 (Denim Black, 32 GB)]  3 GB RAM
# 5          [realme C30 (Bamboo Green, 32 GB)]  3 GB RAM
# 6             [realme C30 (Lake Blue, 32 GB)]  3 GB RAM
# 7     [realme 10 Pro 5G (Hyperspace, 128 GB)]  6 GB RAM
# 8     [realme 10 Pro 5G (Hyperspace, 128 GB)]  8 GB RAM
# 9    [realme 10 Pro 5G (Nebula Blue, 128 GB)]  8 GB RAM
# 10   [realme 10 Pro 5G (Dark Matter, 128 GB)]  6 GB RAM
# 11    [vivo T1 44W (Midnight Galaxy, 128 GB)]  4 GB RAM
# 12  [realme 10 Pro+ 5G (Nebula Blue, 128 GB)]  8 GB RAM
# 13  [realme 10 Pro+ 5G (Dark Matter, 128 GB)]  6 GB RAM
# 14   [realme 10 Pro+ 5G (Hyperspace, 128 GB)]  8 GB RAM
# 15    [vivo T1 44W (Midnight Galaxy, 128 GB)]  6 GB RAM
# ...

# %%
pixel_4A=df.to_csv('pixel_4A.csv')

# %%
pixel_4A

# %%
new_df=pd.read_csv('pixel_4A.csv')
new_df
# Out:
#     Unnamed: 0                                   Brand name        RAM  \
# 0            0     ['Google Pixel 4a (Just Black, 128 GB)']  6 GB RAM
# 1            1          ['realme C30 (Denim Black, 32 GB)']  2 GB RAM
# 2            2            ['realme C30 (Lake Blue, 32 GB)']  2 GB RAM
# 3            3         ['realme C30 (Bamboo Green, 32 GB)']  2 GB RAM
# 4            4          ['realme C30 (Denim Black, 32 GB)']  3 GB RAM
# 5            5         ['realme C30 (Bamboo Green, 32 GB)']  3 GB RAM
# 6            6            ['realme C30 (Lake Blue, 32 GB)']  3 GB RAM
# 7            7    ['realme 10 Pro 5G (Hyperspace, 128 GB)']  6 GB RAM
# 8            8    ['realme 10 Pro 5G (Hyperspace, 128 GB)']  8 GB RAM
# 9            9   ['realme 10 Pro 5G (Nebula Blue, 128 GB)']  8 GB RAM
# 10          10   ['realme 10 Pro 5G (Dark Matter, 128 GB)']  6 GB RAM
# 11          11    ['vivo T1 44W (Midnight Galaxy, 128 GB)']  4 GB RAM
# ...

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
name=[]
os=[]
processor=[]
image_url=[]

# %%
name_tag=driver.find_elements(By.XPATH,'//div[@class="TopNumbeHeading"]')
for i in name_tag:
    name.append(i.text)
    
len(name)
# Out:
# 10

# %%
os_tag=driver.find_elements(By.XPATH,'//div[@class="Specs-Wrap"]')
for i in os_tag:
    os.append(i.text.split('|')[0])

# %%
os
# Out:
# ['Windows 11 Home OS\n17.3" (3840 x 2160) Display\n12th Gen Intel Core i9-12900HX ',
#  'Windows 11 Home OS\n17.3" (1920 x 1080) Display\n12th Gen Intel Core i9-12900H ',
#  'Windows 11 OS\n16" (2560 x 1600) Display\n12th Gen Intel Core i7-12700H ',
#  'Windows 11 Home OS\n16.1" (2560 x 1440) Display\n12th Gen Intel Core i7-12700H ',
#  'Windows 11 Home OS\n15.6" (2560 x 1440) Display\nAMD Ryzen 9-5900HX ',
#  'Windows 11 Home OS\n15.6" (1920 x 1080) Display\nAMD 5th Gen Ryzen 9-5900HX ',
#  'Windows 11 Home OS\n16.1" (2560 x 1440) Display\nAMD Ryzen™ 9 5900HX ',
#  'Windows 11 Home OS\n16" (2560 x 1600) Display\n12th Gen Intel Core i7-12700H ',
#  'Windows 11 Home OS\n15.6" (1920 x 1080) Display\nAMD Ryzen R7-5800H ',
#  'Windows 11 Home OS\n15.6 MP ']

# %%
pros_tag=driver.find_elements(By.XPATH,'//div[@class="Specs-Wrap"]')
for i in pros_tag:
    processor.append(i.text.split('|')[1])

# %%
processor
# Out:
# [' NA Processor\n2 TB SSD/64 GB DDR5 Memory',
#  ' 5 GHz Processor\n1 TB SSD/32 GB DDR5 Memory',
#  ' 3.5 GHz Processor\n2 TB SSD/32 GB DDR5 Memory',
#  ' 4.7 GHz Processor\n1 TB SSD/8 GB DDR5 Memory',
#  ' NA Processor\n512 GB SSD/16 GB DDR4 Memory',
#  ' 3.3GHz Processor\n1 TB SSD/16 GBGB DDR4 Memory',
#  ' 3.3 GHz Processor\n1 TB NVMe/16 GB DDR4 Memory',
#  ' 2.3 GHz Processor\n1 TB SSD/16 GB DDR5 Memory',
#  ' 4.40 GHz Processor\n512 GB SSD/16 GB DDR4 Memory',
#  ' NA Display\nLenovo Ryzen 7-5800H ']

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="lowest_price"]')
for i in price_tag:
    try:
        price.append(i.text.split('|')[0])
    except NoSuchElementException:
        price.append('-')

# %%
price
# Out:
# ['₹ 389,990\nBUY NOW',
#  '₹ 229,990\nBUY NOW',
#  '₹ 176,490\nBUY NOW',
#  '₹ 124,990\nBUY NOW',
#  '₹ 169,990\nBUY NOW',
#  '₹ 174,000\nBUY NOW',
#  '₹ 131,990\nBUY NOW']

# %%
url_tag=driver.find_elements(By.XPATH,'//div[@class="product-ickon"]')
for i in url_tag:
    image_url.append(i.get_attribute('src'))
    
len(image_url)
# Out:
# 10

# %%
df=pd.DataFrame({'BEST_GAMING_LAP_NAME':name[0:7],'OS':os[0:7],'PROCESSOR':processor[0:7],'IMAGES_URL':image_url[0:7],'PRICE':price[0:7]})
df
# Out:
#                         BEST_GAMING_LAP_NAME  \
# 0                   1.\nMSI Titan GT77-12UHS
# 1                       2.\nAlienware X17 R2
# 2  3.\nAcer Predator Triton 500 SE PT516-52s
# 3                4.\nOmen By HP (16-B1371TX)
# 4      5.\nAcer Predator Helios 300 AN515-45
# 5             6.\nMSI Delta 15 (A5EFK-083IN)
# 6                7.\nOmen By HP (16-C0141AX)
#
#                                                   OS  \
# 0  Windows 11 Home OS\n17.3" (3840 x 2160) Displa...
# 1  Windows 11 Home OS\n17.3" (1920 x 1080) Displa...
# 2  Windows 11 OS\n16" (2560 x 1600) Display\n12th...
# 3  Windows 11 Home OS\n16.1" (2560 x 1440) Displa...
# 4  Windows 11 Home OS\n15.6" (2560 x 1440) Displa...
# 5  Windows 11 Home OS\n15.6" (1920 x 1080) Displa...
# 6  Windows 11 Home OS\n16.1" (2560 x 1440) Displa...
#
#                                          PROCESSOR IMAGES_URL  \
# 0         NA Processor\n2 TB SSD/64 GB DDR5 Memory       None
# ...

# %%
df.to_csv('best_gaming_laptops.csv')

# %%
new_df=pd.read_csv('best_gaming_laptops.csv')
new_df
# Out:
#    Unnamed: 0                       BEST_GAMING_LAP_NAME  \
# 0           0                   1.\nMSI Titan GT77-12UHS
# 1           1                       2.\nAlienware X17 R2
# 2           2  3.\nAcer Predator Triton 500 SE PT516-52s
# 3           3                4.\nOmen By HP (16-B1371TX)
# 4           4      5.\nAcer Predator Helios 300 AN515-45
# 5           5             6.\nMSI Delta 15 (A5EFK-083IN)
# 6           6                7.\nOmen By HP (16-C0141AX)
#
#                                                   OS  \
# 0  Windows 11 Home OS\n17.3" (3840 x 2160) Displa...
# 1  Windows 11 Home OS\n17.3" (1920 x 1080) Displa...
# 2  Windows 11 OS\n16" (2560 x 1600) Display\n12th...
# 3  Windows 11 Home OS\n16.1" (2560 x 1440) Displa...
# 4  Windows 11 Home OS\n15.6" (2560 x 1440) Displa...
# 5  Windows 11 Home OS\n15.6" (1920 x 1080) Displa...
# 6  Windows 11 Home OS\n16.1" (2560 x 1440) Displa...
#
#                                          PROCESSOR  IMAGES_URL  \
# ...

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (6)\chromedriver.exe')
driver.get("https://www.forbes.com")

# %%
search=driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
search.click()

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]')
search.click()

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/main/div/section/section[1]/div/div/div[1]/div/div[1]/div[1]/div[2]/a')
search.click()

# %%
rank=[]
name=[]
net_worth=[]
citizenship=[]
source=[] 
age=[]
industry=[]

# %%
rank_tag=driver.find_elements(By.XPATH,'//div[@class="rank"]')
for i in rank_tag:
    rank.append(i.text)
name_tag=driver.find_elements(By.XPATH,'//div[@class="personName"]')
for i in name_tag:
    name.append(i.text)
net_worth_tag=driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
for i in net_worth_tag:
    net_worth.append(i.text)
citizenship_tag=driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for i in citizenship_tag:
    citizenship.append(i.text)
source_tag=driver.find_elements(By.XPATH,'//div[@class="source"]')
for i in source_tag:
    source.append(i.text)
age_tag=driver.find_elements(By.XPATH,'//div[@class="age"]')
for i in age_tag:
    age.append(i.text)
i_tag=driver.find_elements(By.XPATH,'//div[@class="category"]') 
for i in i_tag:
    industry.append(i.text)

# %%
print(len(rank),len(name),len(net_worth),len(citizenship),len(source),len(age),len(industry))
# Out:
# 200 200 200 200 200 200 200

# %%
df=pd.DataFrame(data={'RANK':rank,'NAME':name,'NET_WORTH':net_worth,'CITIZENSHIP':citizenship,'SOURCE':source,'AGE':age,'INDUSTRY':industry},index=range(1,201))
df
# Out:
#      RANK                      NAME NET_WORTH    CITIZENSHIP  \
# 1      1.                 Elon Musk    $219 B  United States
# 2      2.                Jeff Bezos    $171 B  United States
# 3      3.  Bernard Arnault & family    $158 B         France
# 4      4.                Bill Gates    $129 B  United States
# 5      5.            Warren Buffett    $118 B  United States
# ..    ...                       ...       ...            ...
# 196  192.    Marcel Herrmann Telles   $10.3 B         Brazil
# 197  197.                Leon Black     $10 B  United States
# 198  197.                Joe Gebbia     $10 B  United States
# 199  197.              David Geffen     $10 B  United States
# 200  197.                Yu Renrong     $10 B          China
#
#                     SOURCE AGE               INDUSTRY
# 1            Tesla, SpaceX  50             Automotive
# 2                   Amazon  58             Technology
# 3                     LVMH  73       Fashion & Retail
# ...

# %%
df.to_csv('top_billionaires_list_2022.csv')

# %%
new_df=pd.read_csv('top_billionaires_list_2022.csv')
new_df
# Out:
#      Unnamed: 0   RANK                      NAME NET_WORTH    CITIZENSHIP  \
# 0             1    1.0                 Elon Musk    $219 B  United States
# 1             2    2.0                Jeff Bezos    $171 B  United States
# 2             3    3.0  Bernard Arnault & family    $158 B         France
# 3             4    4.0                Bill Gates    $129 B  United States
# 4             5    5.0            Warren Buffett    $118 B  United States
# ..          ...    ...                       ...       ...            ...
# 195         196  192.0    Marcel Herrmann Telles   $10.3 B         Brazil
# 196         197  197.0                Leon Black     $10 B  United States
# 197         198  197.0                Joe Gebbia     $10 B  United States
# 198         199  197.0              David Geffen     $10 B  United States
# 199         200  197.0                Yu Renrong     $10 B          China
#
#                     SOURCE   AGE               INDUSTRY
# ...

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (6)\chromedriver.exe')
driver.get("https://www.hostelworld.com")

# %%
location=driver.find_element(By.CLASS_NAME,"search-input")
location.send_keys('London England')

# %%
search=driver.find_element(By.CLASS_NAME,"label")
search.click()

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[2]/div/span[2]')
search.click()

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[2]/div[2]/div/div[34]/div')
search.click()

# %%
search=driver.find_element(By.CLASS_NAME,"search-button")
search.click()

# %%
name=[] 
dist=[]
rate=[]
t_rev=[]
o_rev=[]
faci=[]
desc=[]
priv_price=[]
dorms_price=[]

# %%
name_tag=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]') 
dist_tag=driver.find_elements(By.XPATH,'//span[@class="description"]')
rate_tag=driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
t_rev_tag=driver.find_elements(By.XPATH,'//div[@class="reviews"]')
o_rev_tag=driver.find_elements(By.XPATH,'//div[@class="keyword"]')
faci_tag=driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
desc_tag=driver.find_elements(By.XPATH,'//div[@class="property-card"]')

# %%
for i in name_tag:
    name.append(i.text)
    
len(name)
# Out:
# 30

# %%
for i in dist_tag:
    dist.append(i.text)
    
len(dist)
# Out:
# 30

# %%
for i in rate_tag:
    rate.append(i.text)
    
len(rate)
# Out:
# 28

# %%
for i in t_rev_tag:
    t_rev.append(i.text)
    
len(t_rev)
# Out:
# 30

# %%
for i in o_rev_tag:
    o_rev.append(i.text)
    
len(o_rev)
# Out:
# 32

# %%
for i in faci_tag:
    faci.append(i.text)
    
len(faci)
# Out:
# 30

# %%
for i in desc_tag:
    desc.append(i.text)
    
len(desc)
# Out:
# 32

# %%
priv_price_tag=driver.find_elements(By.XPATH,'//div[@class="price title-5"]')
dorms_price_tag=driver.find_elements(By.XPATH,'//div[@class="price title-5"]')

# %%
for i in priv_price_tag:
    try:
        priv_price.append(i.text)
        
    except NoSuchElementException:
        priv_price.append('Nan')

# %%
for i in dorms_price_tag:
    try:
        dorms_price.append(i.text)
        
    except NoSuchElementException:
        priv_price.append('Nan')

# %%
print(len(name),len(dist),len(rate),len(t_rev),len(o_rev),len(faci),len(desc),len(priv_price),len(dorms_price))
# Out:
# 30 30 28 30 32 30 32 44 44

# %%
df=pd.DataFrame({'HOSTEL NAME':name[0:25],'DISTANCE FROM CITY CENTER':dist[0:25],'RATINGS':rate[0:25],'Total Reviews':t_rev[0:25],'Overall Reviews':o_rev[0:25],'Facilities':faci[0:25],'Property Description':desc[0:25],'Privates Price':priv_price[0:25],'Dorm Price':dorms_price[0:25]})
df
# Out:
#                                 HOSTEL NAME         DISTANCE FROM CITY CENTER  \
# 0               Wombat's City Hostel London   Hostel - 3.6km from city centre
# 1                  St Christopher's Village   Hostel - 1.8km from city centre
# 2                   Hostel One Notting Hill   Hostel - 5.5km from city centre
# 3                      Urbany Hostel London   Hostel - 5.4km from city centre
# 4                          Generator London     Hostel - 3km from city centre
# 5         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 6               Smart Russell Square Hostel   Hostel - 2.6km from city centre
# 7                   St Christopher's Camden   Hostel - 4.3km from city centre
# 8                        No.8 Seven Sisters     Hostel - 9km from city centre
# 9              No.8 Willesden Hostel London    Hostel - 10km from city centre
# 10               Smart Hyde Park Inn Hostel     Hostel - 5km from city centre
# ...

# %%
df.to_csv('london_hostel_info.csv')

# %%
new_df=pd.read_csv('london_hostel_info.csv')
new_df
# Out:
#     Unnamed: 0                              HOSTEL NAME  \
# 0            0              Wombat's City Hostel London
# 1            1                 St Christopher's Village
# 2            2                  Hostel One Notting Hill
# 3            3                     Urbany Hostel London
# 4            4                         Generator London
# 5            5        Safestay London Elephant & Castle
# 6            6              Smart Russell Square Hostel
# 7            7                  St Christopher's Camden
# 8            8                       No.8 Seven Sisters
# 9            9             No.8 Willesden Hostel London
# 10          10               Smart Hyde Park Inn Hostel
# 11          11  Safestay London Kensington Holland Park
# 12          12                         NX London Hostel
# 13          13                         Astor Museum Inn
# 14          14                  Smart Camden Inn Hostel
# 15          15                           Phoenix Hostel
# ...

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (6)\chromedriver.exe')
driver.get("https://www.youtube.com/watch?v=NXawPaqM9zU")

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
comments=[]
comments_tag=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')
for i in comments_tag:
    comments.append(i.text)

# %%
time=[]
time_tag=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
for i in time_tag:
    time.append(i.text)

# %%
comment_upvote=[]
like_tag=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"]')
for i in like_tag:
    comment_upvote.append(i.text)

# %%
print(len(comments),len(time),len(comment_upvote))
# Out:
# 40 105 80

# %%
comments=[]
comments_tag=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')
for i in comments_tag:
    comments.append(i.text)  
    
len(comments)     # got by continuous scrolling down the comments
# Out:
# 519

# %%
time=[]
time_tag=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
for i in time_tag:
    time.append(i.text)    
    
len(time)
# Out:
# 663

# %%
comment_upvote=[]
like_tag=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"]')
for i in like_tag:
    comment_upvote.append(i.text)  
    
len(comment_upvote)
# Out:
# 1038

# %%
df=pd.DataFrame({'COMMENTS':comments[0:500],'POSTED_TIME':time[0:500],'LIKES':comment_upvote[0:500]})
df
# Out:
#                                               COMMENTS  POSTED_TIME LIKES
# 0    I love his calm, classy and soothing voice. Ha...
# 1    Aww no sabia que tenia mas canciones para esta...                 10
# 2    Nothing like Christmas music all year round I ...
# 3    TIME LINE \n0:00 Holy Joly Christmas \n2:03 It...    Music Box
# 4    0:00 Holy Joly Christmas \n\n2:03 It’s a Begin...
# ..                                                 ...          ...   ...
# 495          Wow................ michel  bublé is good  3 weeks ago     3
# 496                  Merry Christmas from Michigan!!!!  2 weeks ago
# 497                                                     4 weeks ago
# 498                                     Mery Christmas  1 month ago
# 499                                         Christmas   4 weeks ago
#
# [500 rows x 3 columns]

# %%
df.to_csv('michael_bubble_christmas_songs_playlist_youtube.csv')

# %%
new_df=pd.read_csv('michael_bubble_christmas_songs_playlist_youtube.csv')
new_df
# Out:
#      Unnamed: 0                                           COMMENTS  \
# 0             0  I love his calm, classy and soothing voice. Ha...
# 1             1  Aww no sabia que tenia mas canciones para esta...
# 2             2  Nothing like Christmas music all year round I ...
# 3             3  TIME LINE \n0:00 Holy Joly Christmas \n2:03 It...
# 4             4  0:00 Holy Joly Christmas \n\n2:03 It’s a Begin...
# ..          ...                                                ...
# 495         495          Wow................ michel  bublé is good
# 496         496                  Merry Christmas from Michigan!!!!
# 497         497                                                NaN
# 498         498                                     Mery Christmas
# 499         499                                         Christmas
#
#      POSTED_TIME  LIKES
# 0            NaN    NaN
# 1            NaN   10.0
# 2            NaN    NaN
# 3      Music Box    NaN
# 4            NaN    NaN
# ...

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (5)\chromedriver.exe')
driver.get( "https://www.amazon.in/s?k=guitar&crid=R7A1ZP2MI9BB&sprefix=guitar%2Caps%2C1920&ref=nb_sb_noss_1")

# %%
product=input('Enter any product: ')
# Out:
# Enter any product: guitar

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (5)\chromedriver.exe')
driver.get( "https://www.amazon.in/s?k=guitar&crid=R7A1ZP2MI9BB&sprefix=guitar%2Caps%2C1920&ref=nb_sb_noss_1")

# %%
brand=[]

price=[]

exp_delivery=[]

url=[]

# %%
for pages in range(0,3):
    try:
        b_tag=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]')
        p_tag=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
        ed_tag=driver.find_elements(By.XPATH,'//div[@class="a-row s-align-children-center"]')
        url_tag=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
        
        for i in b_tag:
            brand.append(i.text)
    
        for i in p_tag:
            price.append(i.text)
    
        for i in ed_tag:
            exp_delivery.append(i.text)
            
        for i in url_tag:
            url.append(i.text)
            
    except NoSuchElementException:
        brand.append('-')
        name.append('-')
        price.append('-')
        exp_delivery('-')
        url.append('-')
    
        next_button=driver.find_elements(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
        next_button.click()
        time.sleep(3)

# %%
print(len(brand),len(price),len(exp_delivery),len(url))
# Out:
# 180 207 165 198

# %%
df=pd.DataFrame({'BRAND_NAME':brand[0:150],'PRICE':price[0:150],'EXPECTED_DELIVERY':exp_delivery[0:150],'PRODUCT_URL':product[0:150]})
df
# Out:
#                                             BRAND_NAME   PRICE  \
# 0    Kadence Slowhand Premium Jumbo Semi Acoustic G...   6,299
# 1    Medellin M38 carbon fiber body 38 Incheses Aco...   9,900
# 2    Medellin 38" Acoustic Guitar premium wood with...   4,949
# 3    Intern 38C Ebony Wood Cutaway Design Acoustic ...   9,900
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   2,428
# ..                                                 ...     ...
# 145  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...   2,149
# 146  Ibanez MD39C-NT Acoustic Guitar (Natural), Des...   2,299
# 147  JUAREZ JRZ38C 38 Inches Lindenwood Right Hande...   2,399
# 148  YAMAHA F310, 6-Strings Rose Wood Acoustic Guit...   6,998
# 149  Medellin M38 carbon fiber body 38 Incheses Aco...  12,499
#
#                    EXPECTED_DELIVERY PRODUCT_URL
# 0    Get it by Tomorrow, December 25      guitar
# 1    Get it by Tomorrow, December 25      guitar
# 2    Get it by Tomorrow, December 25      guitar
# ...

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get('https://images.google.com')

# %%
destinations=driver.find_element(By.CLASS_NAME,"gLFyf")
destinations.send_keys('fruits images')

# %%
search=driver.find_element(By.CLASS_NAME,"Tg7LZd")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
fruit_images=[]
f_tag=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in f_tag[0:10]:
    fruit_images.append(i.get_attribute('src'))
    
len(fruit_images)
# Out:
# 10

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get('https://images.google.com')

# %%
destinations=driver.find_element(By.CLASS_NAME,"gLFyf")
destinations.send_keys('cars images')

# %%
search=driver.find_element(By.CLASS_NAME,"Tg7LZd")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")

# %%
car_images=[]
c_tag=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in c_tag[0:10]:
    car_images.append(i.get_attribute('src'))
    
len(car_images)
# Out:
# 10

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get('https://images.google.com')

# %%
destinations=driver.find_element(By.CLASS_NAME,"gLFyf")
destinations.send_keys('Machine Learning images')

# %%
search=driver.find_element(By.CLASS_NAME,"Tg7LZd")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
ml_images=[]
ml_tag=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in ml_tag[0:10]:
    ml_images.append(i.get_attribute('src'))
    
len(ml_images)
# Out:
# 10

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get('https://images.google.com')

# %%
destinations=driver.find_element(By.CLASS_NAME,"gLFyf")
destinations.send_keys('Guitar images')

# %%
search=driver.find_element(By.CLASS_NAME,"Tg7LZd")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
gu_images=[]
gu_tag=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in gu_tag[0:10]:
    gu_images.append(i.get_attribute('src'))
    
len(gu_images)
# Out:
# 10

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get('https://images.google.com')

# %%
destinations=driver.find_element(By.CLASS_NAME,"gLFyf")
destinations.send_keys('cakes images')

# %%
search=driver.find_element(By.CLASS_NAME,"Tg7LZd")
search.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,500)")

# %%
ck_images=[]
ck_tag=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in ck_tag[0:10]:
    ck_images.append(i.get_attribute('src'))
    
len(ck_images)
# Out:
# 10

# %%
for i in ck_images:
    driver.get(i)
    file=open(r'C:\Users\S.Ramaa Devi\Desktop\New folder\cake_images.jpg','wb')

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver=webdriver.Chrome(r'C:\Users\S.Ramaa Devi\Downloads\chromedriver_win32 (4)\chromedriver.exe')
driver.get('https://www.google.com/maps/@10.7828364,78.2885026,7z')

# %%
designations=driver.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
designations.send_keys('MADURAI')

# %%
search=driver.find_element(By.XPATH,'//div[@class="pzfvzf"]')
search.click()

# %%
url='https://www.google.com/maps/place/Madurai,+Tamil+Nadu/@9.9178368,78.1228237,12z/data=!3m1!4b1!4m5!3m4!1s0x3b00c582b1189633:0xdc955b7264f63933!8m2!3d9.9252007!4d78.1197754'
url_tag=driver.get(url)
print('Url_extracted: ' ,url_tag)
lat_long=url_tag(r'@(.*)data',url_tag)
# Out:
# Url_extracted:  None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [136], in <cell line: 4>()
#       2 url_tag=driver.get(url)
#       3 print('Url_extracted: ' ,url_tag)
# ----> 4 lat_long=url_tag(r'@(.*)data',url_tag)
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# I cannot scrap more from the above sum .
